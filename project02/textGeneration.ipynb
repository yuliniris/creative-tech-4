# %%
def generateTable(text, k):
    T= {}
    for i in range(len(text)-k):
        x = text[i:i+k]
        y = text[i+k]
        
        if T.get(x) is None:
            T[x] ={}
            T[x][y]=1
        else:
            if T[x].get(y) is None:
                T[x][y] =1
            else:
                T[x][y]+=1
    return T

# %%
T = generateTable ("Waymo’s application to expand its robotaxi service in Los Angeles and San Mateo counties has been suspended for 120 days by the California Public Utilities Commission’s Consumer Protection and Enforcement Division.The decision doesn’t change Waymo’s ability to commercially operate driverless vehicles in San Francisco." , 3)

# %%
T
# Out:
# {'Way': {'m': 1.0},
#  'aym': {'o': 1.0},
#  'ymo': {'’': 1.0},
#  'mo’': {'s': 1.0},
#  'o’s': {' ': 1.0},
#  '’s ': {'a': 0.6666666666666666, 'C': 0.3333333333333333},
#  's a': {'p': 0.3333333333333333,
#   'n': 0.3333333333333333,
#   'b': 0.3333333333333333},
#  ' ap': {'p': 1.0},
#  'app': {'l': 1.0},
#  'ppl': {'i': 1.0},
#  'pli': {'c': 1.0},
#  'lic': {'a': 0.5, ' ': 0.5},
#  'ica': {'t': 1.0},
#  'cat': {'i': 1.0},
#  'ati': {'o': 1.0},
#  'tio': {'n': 1.0},
#  'ion': {' ': 0.6, '’': 0.2, '.': 0.2},
#  'on ': {'t': 0.3333333333333333,
#   'a': 0.3333333333333333,
#   'd': 0.3333333333333333},
#  'n t': {'o': 1.0},
#  ' to': {' ': 1.0},
#  'to ': {'e': 0.5, 'c': 0.5},
#  'o e': {'x': 1.0},
#  ' ex': {'p': 1.0},
#  'exp': {'a': 1.0},
#  'xpa': {'n': 1.0},
#  'pan': {'d': 1.0},
#  'and': {' ': 1.0},
#  'nd ': {'i': 0.3333333333333333,
#   'S': 0.3333333333333333,
#   'E': 0.3333333333333333},
#  'd i': {'t': 1.0},
#  ' it': {'s': 1.0},
#  'its': {' ': 1.0},
#  'ts ': {'r': 1.0},
#  's r': {'o': 1.0},
#  ' ro': {'b': 1.0},
#  'rob': {'o': 1.0},
#  'obo': {'t': 1.0},
#  'bot': {'a': 1.0},
#  'ota': {'x': 1.0},
#  'tax': {'i': 1.0},
#  'axi': {' ': 1.0},
#  'xi ': {'s': 1.0},
#  'i s': {'e': 1.0},
#  ' se': {'r': 1.0},
#  'ser': {'v': 1.0},
#  'erv': {'i': 1.0},
#  'rvi': {'c': 1.0},
#  'vic': {'e': 1.0},
#  'ice': {' ': 1.0},
#  'ce ': {'i': 1.0},
#  'e i': {'n': 1.0},
#  ' in': {' ': 1.0},
#  'in ': {'L': 0.5, 'S': 0.5},
#  'n L': {'o': 1.0},
#  ' Lo': {'s': 1.0},
#  'Los': {' ': 1.0},
#  'os ': {'A': 1.0},
#  's A': {'n': 1.0},
#  ' An': {'g': 1.0},
#  'Ang': {'e': 1.0},
#  'nge': {'l': 0.5, ' ': 0.5},
#  'gel': {'e': 1.0},
#  'ele': {'s': 1.0},
#  'les': {' ': 0.6666666666666666, 's': 0.3333333333333333},
#  'es ': {'a': 0.25, 'h': 0.25, 'C': 0.25, 'i': 0.25},
#  ' an': {'d': 1.0},
#  'd S': {'a': 1.0},
#  ' Sa': {'n': 1.0},
#  'San': {' ': 1.0},
#  'an ': {'M': 0.5, 'F': 0.5},
#  'n M': {'a': 1.0},
#  ' Ma': {'t': 1.0},
#  'Mat': {'e': 1.0},
#  'ate': {'o': 0.5, ' ': 0.5},
#  'teo': {' ': 1.0},
#  'eo ': {'c': 1.0},
#  'o c': {'o': 1.0},
#  ' co': {'u': 0.5, 'm': 0.5},
#  'cou': {'n': 1.0},
#  'oun': {'t': 1.0},
#  'unt': {'i': 1.0},
#  'nti': {'e': 1.0},
#  'tie': {'s': 1.0},
#  'ies': {' ': 1.0},
#  's h': {'a': 1.0},
#  ' ha': {'s': 1.0},
#  'has': {' ': 1.0},
#  'as ': {'b': 1.0},
#  's b': {'e': 0.5, 'y': 0.5},
#  ' be': {'e': 1.0},
#  'bee': {'n': 1.0},
#  'een': {' ': 1.0},
#  'en ': {'s': 1.0},
#  'n s': {'u': 1.0},
#  ' su': {'s': 1.0},
#  'sus': {'p': 1.0},
#  'usp': {'e': 1.0},
#  'spe': {'n': 1.0},
#  'pen': {'d': 1.0},
#  'end': {'e': 1.0},
#  'nde': {'d': 1.0},
#  'ded': {' ': 1.0},
#  'ed ': {'f': 1.0},
#  'd f': {'o': 1.0},
#  ' fo': {'r': 1.0},
#  'for': {' ': 0.3333333333333333,
#   'n': 0.3333333333333333,
#   'c': 0.3333333333333333},
#  'or ': {'1': 1.0},
#  'r 1': {'2': 1.0},
#  ' 12': {'0': 1.0},
#  '120': {' ': 1.0},
#  '20 ': {'d': 1.0},
#  '0 d': {'a': 1.0},
#  ' da': {'y': 1.0},
#  'day': {'s': 1.0},
#  'ays': {' ': 1.0},
#  'ys ': {'b': 1.0},
#  ' by': {' ': 1.0},
#  'by ': {'t': 1.0},
#  'y t': {'h': 0.5, 'o': 0.5},
#  ' th': {'e': 1.0},
#  'the': {' ': 1.0},
#  'he ': {'C': 0.5, 'd': 0.5},
#  'e C': {'a': 1.0},
#  ' Ca': {'l': 1.0},
#  'Cal': {'i': 1.0},
#  'ali': {'f': 1.0},
#  'lif': {'o': 1.0},
#  'ifo': {'r': 1.0},
#  'orn': {'i': 1.0},
#  'rni': {'a': 1.0},
#  'nia': {' ': 1.0},
#  'ia ': {'P': 1.0},
#  'a P': {'u': 1.0},
#  ' Pu': {'b': 1.0},
#  'Pub': {'l': 1.0},
#  'ubl': {'i': 1.0},
#  'bli': {'c': 1.0},
#  'ic ': {'U': 1.0},
#  'c U': {'t': 1.0},
#  ' Ut': {'i': 1.0},
#  'Uti': {'l': 1.0},
#  'til': {'i': 1.0},
#  'ili': {'t': 1.0},
#  'lit': {'i': 0.5, 'y': 0.5},
#  'iti': {'e': 1.0},
#  's C': {'o': 1.0},
#  ' Co': {'m': 0.5, 'n': 0.5},
#  'Com': {'m': 1.0},
#  'omm': {'i': 0.5, 'e': 0.5},
#  'mmi': {'s': 1.0},
#  'mis': {'s': 1.0},
#  'iss': {'i': 1.0},
#  'ssi': {'o': 1.0},
#  'sio': {'n': 1.0},
#  'on’': {'s': 1.0},
#  'n’s': {' ': 1.0},
#  'Con': {'s': 1.0},
#  'ons': {'u': 1.0},
#  'nsu': {'m': 1.0},
#  'sum': {'e': 1.0},
#  'ume': {'r': 1.0},
#  'mer': {' ': 0.5, 'c': 0.5},
#  'er ': {'P': 1.0},
#  'r P': {'r': 1.0},
#  ' Pr': {'o': 1.0},
#  'Pro': {'t': 1.0},
#  'rot': {'e': 1.0},
#  'ote': {'c': 1.0},
#  'tec': {'t': 1.0},
#  'ect': {'i': 1.0},
#  'cti': {'o': 1.0},
#  'n a': {'n': 1.0},
#  'd E': {'n': 1.0},
#  ' En': {'f': 1.0},
#  'Enf': {'o': 1.0},
#  'nfo': {'r': 1.0},
#  'orc': {'e': 1.0},
#  'rce': {'m': 1.0},
#  'cem': {'e': 1.0},
#  'eme': {'n': 1.0},
#  'men': {'t': 1.0},
#  'ent': {' ': 1.0},
#  'nt ': {'D': 1.0},
#  't D': {'i': 1.0},
#  ' Di': {'v': 1.0},
#  'Div': {'i': 1.0},
#  'ivi': {'s': 1.0},
#  'vis': {'i': 1.0},
#  'isi': {'o': 1.0},
#  'on.': {'T': 1.0},
#  'n.T': {'h': 1.0},
#  '.Th': {'e': 1.0},
#  'The': {' ': 1.0},
#  'e d': {'e': 0.5, 'r': 0.5},
#  ' de': {'c': 1.0},
#  'dec': {'i': 1.0},
#  'eci': {'s': 1.0},
#  'cis': {'i': 0.5, 'c': 0.5},
#  'n d': {'o': 1.0},
#  ' do': {'e': 1.0},
#  'doe': {'s': 1.0},
#  'oes': {'n': 1.0},
#  'esn': {'’': 1.0},
#  'sn’': {'t': 1.0},
#  'n’t': {' ': 1.0},
#  '’t ': {'c': 1.0},
#  't c': {'h': 1.0},
#  ' ch': {'a': 1.0},
#  'cha': {'n': 1.0},
#  'han': {'g': 1.0},
#  'ang': {'e': 1.0},
#  'ge ': {'W': 1.0},
#  'e W': {'a': 1.0},
#  ' Wa': {'y': 1.0},
#  ' ab': {'i': 1.0},
#  'abi': {'l': 1.0},
#  'bil': {'i': 1.0},
#  'ity': {' ': 1.0},
#  'ty ': {'t': 1.0},
#  'com': {'m': 1.0},
#  'mme': {'r': 1.0},
#  'erc': {'i': 1.0},
#  'rci': {'a': 1.0},
#  'cia': {'l': 1.0},
#  'ial': {'l': 1.0},
#  'all': {'y': 1.0},
#  'lly': {' ': 1.0},
#  'ly ': {'o': 1.0},
#  'y o': {'p': 1.0},
#  ' op': {'e': 1.0},
#  'ope': {'r': 1.0},
#  'per': {'a': 1.0},
#  'era': {'t': 1.0},
#  'rat': {'e': 1.0},
#  'te ': {'d': 1.0},
#  ' dr': {'i': 1.0},
#  'dri': {'v': 1.0},
#  'riv': {'e': 1.0},
#  'ive': {'r': 1.0},
#  'ver': {'l': 1.0},
#  'erl': {'e': 1.0},
#  'rle': {'s': 1.0},
#  'ess': {' ': 1.0},
#  'ss ': {'v': 1.0},
#  's v': {'e': 1.0},
#  ' ve': {'h': 1.0},
#  'veh': {'i': 1.0},
#  'ehi': {'c': 1.0},
#  'hic': {'l': 1.0},
#  'icl': {'e': 1.0},
#  'cle': {'s': 1.0},
#  's i': {'n': 1.0},
#  'n S': {'a': 1.0},
#  'n F': {'r': 1.0},
#  ' Fr': {'a': 1.0},
#  'Fra': {'n': 1.0},
#  'ran': {'c': 1.0},
#  'anc': {'i': 1.0},
#  'nci': {'s': 1.0},
#  'isc': {'o': 1.0},
#  'sco': {'.': 1.0}}

# %%
def convertToProb (T):
    for kx in T.keys():
        s = sum(T[kx].values())
        for k in T[kx].keys():
            T[kx][k] =T[kx][k]/s
            
    return T

# %%
convertToProb(T)
# Out:
# {'Way': {'m': 1.0},
#  'aym': {'o': 1.0},
#  'ymo': {'’': 1.0},
#  'mo’': {'s': 1.0},
#  'o’s': {' ': 1.0},
#  '’s ': {'a': 0.6666666666666666, 'C': 0.3333333333333333},
#  's a': {'p': 0.3333333333333333,
#   'n': 0.3333333333333333,
#   'b': 0.3333333333333333},
#  ' ap': {'p': 1.0},
#  'app': {'l': 1.0},
#  'ppl': {'i': 1.0},
#  'pli': {'c': 1.0},
#  'lic': {'a': 0.5, ' ': 0.5},
#  'ica': {'t': 1.0},
#  'cat': {'i': 1.0},
#  'ati': {'o': 1.0},
#  'tio': {'n': 1.0},
#  'ion': {' ': 0.6, '’': 0.2, '.': 0.2},
#  'on ': {'t': 0.3333333333333333,
#   'a': 0.3333333333333333,
#   'd': 0.3333333333333333},
#  'n t': {'o': 1.0},
#  ' to': {' ': 1.0},
#  'to ': {'e': 0.5, 'c': 0.5},
#  'o e': {'x': 1.0},
#  ' ex': {'p': 1.0},
#  'exp': {'a': 1.0},
#  'xpa': {'n': 1.0},
#  'pan': {'d': 1.0},
#  'and': {' ': 1.0},
#  'nd ': {'i': 0.3333333333333333,
#   'S': 0.3333333333333333,
#   'E': 0.3333333333333333},
#  'd i': {'t': 1.0},
#  ' it': {'s': 1.0},
#  'its': {' ': 1.0},
#  'ts ': {'r': 1.0},
#  's r': {'o': 1.0},
#  ' ro': {'b': 1.0},
#  'rob': {'o': 1.0},
#  'obo': {'t': 1.0},
#  'bot': {'a': 1.0},
#  'ota': {'x': 1.0},
#  'tax': {'i': 1.0},
#  'axi': {' ': 1.0},
#  'xi ': {'s': 1.0},
#  'i s': {'e': 1.0},
#  ' se': {'r': 1.0},
#  'ser': {'v': 1.0},
#  'erv': {'i': 1.0},
#  'rvi': {'c': 1.0},
#  'vic': {'e': 1.0},
#  'ice': {' ': 1.0},
#  'ce ': {'i': 1.0},
#  'e i': {'n': 1.0},
#  ' in': {' ': 1.0},
#  'in ': {'L': 0.5, 'S': 0.5},
#  'n L': {'o': 1.0},
#  ' Lo': {'s': 1.0},
#  'Los': {' ': 1.0},
#  'os ': {'A': 1.0},
#  's A': {'n': 1.0},
#  ' An': {'g': 1.0},
#  'Ang': {'e': 1.0},
#  'nge': {'l': 0.5, ' ': 0.5},
#  'gel': {'e': 1.0},
#  'ele': {'s': 1.0},
#  'les': {' ': 0.6666666666666666, 's': 0.3333333333333333},
#  'es ': {'a': 0.25, 'h': 0.25, 'C': 0.25, 'i': 0.25},
#  ' an': {'d': 1.0},
#  'd S': {'a': 1.0},
#  ' Sa': {'n': 1.0},
#  'San': {' ': 1.0},
#  'an ': {'M': 0.5, 'F': 0.5},
#  'n M': {'a': 1.0},
#  ' Ma': {'t': 1.0},
#  'Mat': {'e': 1.0},
#  'ate': {'o': 0.5, ' ': 0.5},
#  'teo': {' ': 1.0},
#  'eo ': {'c': 1.0},
#  'o c': {'o': 1.0},
#  ' co': {'u': 0.5, 'm': 0.5},
#  'cou': {'n': 1.0},
#  'oun': {'t': 1.0},
#  'unt': {'i': 1.0},
#  'nti': {'e': 1.0},
#  'tie': {'s': 1.0},
#  'ies': {' ': 1.0},
#  's h': {'a': 1.0},
#  ' ha': {'s': 1.0},
#  'has': {' ': 1.0},
#  'as ': {'b': 1.0},
#  's b': {'e': 0.5, 'y': 0.5},
#  ' be': {'e': 1.0},
#  'bee': {'n': 1.0},
#  'een': {' ': 1.0},
#  'en ': {'s': 1.0},
#  'n s': {'u': 1.0},
#  ' su': {'s': 1.0},
#  'sus': {'p': 1.0},
#  'usp': {'e': 1.0},
#  'spe': {'n': 1.0},
#  'pen': {'d': 1.0},
#  'end': {'e': 1.0},
#  'nde': {'d': 1.0},
#  'ded': {' ': 1.0},
#  'ed ': {'f': 1.0},
#  'd f': {'o': 1.0},
#  ' fo': {'r': 1.0},
#  'for': {' ': 0.3333333333333333,
#   'n': 0.3333333333333333,
#   'c': 0.3333333333333333},
#  'or ': {'1': 1.0},
#  'r 1': {'2': 1.0},
#  ' 12': {'0': 1.0},
#  '120': {' ': 1.0},
#  '20 ': {'d': 1.0},
#  '0 d': {'a': 1.0},
#  ' da': {'y': 1.0},
#  'day': {'s': 1.0},
#  'ays': {' ': 1.0},
#  'ys ': {'b': 1.0},
#  ' by': {' ': 1.0},
#  'by ': {'t': 1.0},
#  'y t': {'h': 0.5, 'o': 0.5},
#  ' th': {'e': 1.0},
#  'the': {' ': 1.0},
#  'he ': {'C': 0.5, 'd': 0.5},
#  'e C': {'a': 1.0},
#  ' Ca': {'l': 1.0},
#  'Cal': {'i': 1.0},
#  'ali': {'f': 1.0},
#  'lif': {'o': 1.0},
#  'ifo': {'r': 1.0},
#  'orn': {'i': 1.0},
#  'rni': {'a': 1.0},
#  'nia': {' ': 1.0},
#  'ia ': {'P': 1.0},
#  'a P': {'u': 1.0},
#  ' Pu': {'b': 1.0},
#  'Pub': {'l': 1.0},
#  'ubl': {'i': 1.0},
#  'bli': {'c': 1.0},
#  'ic ': {'U': 1.0},
#  'c U': {'t': 1.0},
#  ' Ut': {'i': 1.0},
#  'Uti': {'l': 1.0},
#  'til': {'i': 1.0},
#  'ili': {'t': 1.0},
#  'lit': {'i': 0.5, 'y': 0.5},
#  'iti': {'e': 1.0},
#  's C': {'o': 1.0},
#  ' Co': {'m': 0.5, 'n': 0.5},
#  'Com': {'m': 1.0},
#  'omm': {'i': 0.5, 'e': 0.5},
#  'mmi': {'s': 1.0},
#  'mis': {'s': 1.0},
#  'iss': {'i': 1.0},
#  'ssi': {'o': 1.0},
#  'sio': {'n': 1.0},
#  'on’': {'s': 1.0},
#  'n’s': {' ': 1.0},
#  'Con': {'s': 1.0},
#  'ons': {'u': 1.0},
#  'nsu': {'m': 1.0},
#  'sum': {'e': 1.0},
#  'ume': {'r': 1.0},
#  'mer': {' ': 0.5, 'c': 0.5},
#  'er ': {'P': 1.0},
#  'r P': {'r': 1.0},
#  ' Pr': {'o': 1.0},
#  'Pro': {'t': 1.0},
#  'rot': {'e': 1.0},
#  'ote': {'c': 1.0},
#  'tec': {'t': 1.0},
#  'ect': {'i': 1.0},
#  'cti': {'o': 1.0},
#  'n a': {'n': 1.0},
#  'd E': {'n': 1.0},
#  ' En': {'f': 1.0},
#  'Enf': {'o': 1.0},
#  'nfo': {'r': 1.0},
#  'orc': {'e': 1.0},
#  'rce': {'m': 1.0},
#  'cem': {'e': 1.0},
#  'eme': {'n': 1.0},
#  'men': {'t': 1.0},
#  'ent': {' ': 1.0},
#  'nt ': {'D': 1.0},
#  't D': {'i': 1.0},
#  ' Di': {'v': 1.0},
#  'Div': {'i': 1.0},
#  'ivi': {'s': 1.0},
#  'vis': {'i': 1.0},
#  'isi': {'o': 1.0},
#  'on.': {'T': 1.0},
#  'n.T': {'h': 1.0},
#  '.Th': {'e': 1.0},
#  'The': {' ': 1.0},
#  'e d': {'e': 0.5, 'r': 0.5},
#  ' de': {'c': 1.0},
#  'dec': {'i': 1.0},
#  'eci': {'s': 1.0},
#  'cis': {'i': 0.5, 'c': 0.5},
#  'n d': {'o': 1.0},
#  ' do': {'e': 1.0},
#  'doe': {'s': 1.0},
#  'oes': {'n': 1.0},
#  'esn': {'’': 1.0},
#  'sn’': {'t': 1.0},
#  'n’t': {' ': 1.0},
#  '’t ': {'c': 1.0},
#  't c': {'h': 1.0},
#  ' ch': {'a': 1.0},
#  'cha': {'n': 1.0},
#  'han': {'g': 1.0},
#  'ang': {'e': 1.0},
#  'ge ': {'W': 1.0},
#  'e W': {'a': 1.0},
#  ' Wa': {'y': 1.0},
#  ' ab': {'i': 1.0},
#  'abi': {'l': 1.0},
#  'bil': {'i': 1.0},
#  'ity': {' ': 1.0},
#  'ty ': {'t': 1.0},
#  'com': {'m': 1.0},
#  'mme': {'r': 1.0},
#  'erc': {'i': 1.0},
#  'rci': {'a': 1.0},
#  'cia': {'l': 1.0},
#  'ial': {'l': 1.0},
#  'all': {'y': 1.0},
#  'lly': {' ': 1.0},
#  'ly ': {'o': 1.0},
#  'y o': {'p': 1.0},
#  ' op': {'e': 1.0},
#  'ope': {'r': 1.0},
#  'per': {'a': 1.0},
#  'era': {'t': 1.0},
#  'rat': {'e': 1.0},
#  'te ': {'d': 1.0},
#  ' dr': {'i': 1.0},
#  'dri': {'v': 1.0},
#  'riv': {'e': 1.0},
#  'ive': {'r': 1.0},
#  'ver': {'l': 1.0},
#  'erl': {'e': 1.0},
#  'rle': {'s': 1.0},
#  'ess': {' ': 1.0},
#  'ss ': {'v': 1.0},
#  's v': {'e': 1.0},
#  ' ve': {'h': 1.0},
#  'veh': {'i': 1.0},
#  'ehi': {'c': 1.0},
#  'hic': {'l': 1.0},
#  'icl': {'e': 1.0},
#  'cle': {'s': 1.0},
#  's i': {'n': 1.0},
#  'n S': {'a': 1.0},
#  'n F': {'r': 1.0},
#  ' Fr': {'a': 1.0},
#  'Fra': {'n': 1.0},
#  'ran': {'c': 1.0},
#  'anc': {'i': 1.0},
#  'nci': {'s': 1.0},
#  'isc': {'o': 1.0},
#  'sco': {'.': 1.0}}

# %%
def readText (filepath):
    with open(filepath) as f:
        return f.read().lower()

# %%
text = readText('./textForTest.txt')

# %%
print(text)
# Out:
# waymo’s application to expand its robotaxi service in los angeles and san mateo counties has been suspended for 120 days by the california public utilities commission’s consumer protection and enforcement division.
#
# the decision doesn’t change waymo’s ability to commercially operate driverless vehicles in san francisco. however, it does put an abrupt halt to the company’s aspirations to expand where it can operate — at least until june 2024.
#
# the cped said on its website that the application has been suspended for further staff review. the “suspension” of an advice letter is a procedural part of the cpuc’s standard and robust review process, according to waymo.
#
# san mateo county board of supervisors vice president david j. canepa took a different stance, however.
#
# “since waymo has stalled any meaningful discussions on its expansion plans into silicon valley, the cpuc has put the brakes on its application to test robotaxi service virtually unfettered both in san mateo and los angeles counties,” canepa said. “this will provide the opportunity to fully engage the autonomous vehicle maker on our very real public safety concerns that have caused all kinds of dangerous situations for firefighters and police in neighboring san francisco.”
#
# waymo noted that it has reached out to two dozen government and business organizations as part of its outreach effort, including officials in cities throughout san mateo county such as burlingame, daly city and foster city, the san mateo county sheriff’s office and local chambers of commerce.
#
# waymo operates a commercial service 24 hours a day, seven days a week throughout san francisco. waymo is also allowed to give people free driverless rides in parts of los angeles. the company kicked off robotaxi ride testing with employees in santa monica around march 2023 and has since opened it up to some members of the public, but is still not able to charge for those rides.

# %% [markdown]
# Train Markov Chains

# %%
def trainMarkovChain(text, k):
    T = generateTable(text, k)
    T = convertToProb(T)
    
    return T

# %%
model = trainMarkovChain(text, 3)

# %%
import random

# %%
def sampleNext(prompt,T,k):
    prompt = prompt[-k:]
    
    if T.get(prompt) is None:
        return " "
    
    chars = list(T.get(prompt).keys())
    probs = list(T.get(prompt).values())
    return random.choices(chars, weights=probs)[0]

# %%
sampleNext("i am fine", model, 3)
# Out:
# 's'

# %%
def generateText(starting, T, k, maxlen):
    sentence = starting
    prompt = starting[-k:]
    
    for i in range(maxlen):
        next = sampleNext(prompt, T, k)
        sentence += next
        prompt = sentence[-k:]
        
    return sentence

# %%
generateText('what is the news today',model, k = 3, maxlen=700)
# Out:
# 'what is the news today, servision ange the can operationsumercement san francision plans on it has rides as rident dozen san mates part of suspended ally city the cal parts robotaxi service it canepa said. “this ally unfety sher stil june 2024.\n\nthe cpuc’s and wher staff robusiness, according san francisco. waymo’s and robusince in san france waymo’s stand wher stally unty botaxi servisors organization able meanizations for the brakes applice publicons foster is sility, the angeles has burlingame, howed its of the opportunity shere in suspened the said outreal seven goverles. the cpuc have put abrupt has stall not angeless rides con it can franciscussion it canepa safetterent safetter stance, day, seven days aspi'
