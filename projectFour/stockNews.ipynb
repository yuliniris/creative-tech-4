# %%
import requests

STOCK_NAME = "TSLA"
COMPANY_NAME = "Tesla Inc"

STOCK_ENDPOINT = "https://www.alphavantage.co/query"
NEWS_ENDPOINT = "https://newsapi.org/v2/everything"

# Alpha Vantage! Here is your API key: H9LV9ISMULZP2NKX. 
stockAPIKey ="H9LV9ISMULZP2NKX"

  
stock_params = {
    "function":"TIME_SERIES_DAILY",
    "symbol":STOCK_NAME,
    "apikey":stockAPIKey,


}

response = requests.get(STOCK_ENDPOINT, params=stock_params)
data = response.json()["Time Series (Daily)"]
dataList = [value for (key, value) in data.items()]
yesterdayData = dataList[0]
yesterdayClosingPrice = yesterdayData["4. close"]
print(yesterdayClosingPrice)
# Out:
# 176.8800

# %%
dayBeforeYesterday = dataList[1]
dayBeforeYesterdayClosingPrice = dayBeforeYesterday["4. close"]
print(dayBeforeYesterdayClosingPrice)
# Out:
# 172.9800

# %%
difference = abs(float(yesterdayClosingPrice) - float(dayBeforeYesterdayClosingPrice))
print(difference)
# Out:
# 3.9000000000000057

# %%
diffPercent = (difference / float(yesterdayClosingPrice))*100
print(diffPercent)
# Out:
# 2.2048846675712377

# %% [markdown]
# Your API key is: 5e82f2f49cc4453ca2b4c46119529ac2
# https://newsapi.org/docs

# %%
NEWS_ENDPOINT = "https://newsapi.org/v2/everything"
NEWS_API_KEY = "5e82f2f49cc4453ca2b4c46119529ac2"

if diffPercent > 2:
    news_params ={
    "apiKey" : NEWS_API_KEY,
    "q" : COMPANY_NAME,
    "searchIn": "title",
    
    
    }
    news_response = requests.get(NEWS_ENDPOINT, params=news_params)
    articles = news_response.json()["articles"]
    print(articles)
# Out:
# [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'GuruFocus Research', 'title': 'Director Robyn Denholm Sells 93,705 Shares of Tesla Inc (TSLA)', 'description': 'Tesla Inc (NASDAQ:TSLA) experienced a notable insider sell on March 12, 2024, according to a recent SEC filing.', 'url': 'https://finance.yahoo.com/news/director-robyn-denholm-sells-93-054909107.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/br9qC.j2W5V0SlLpFN5Uzw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD01MjU-/https://media.zenfs.com/en/us.finance.gurufocus/9743aa0b0ee97fcab89e0e9854bfb79c', 'publishedAt': '2024-03-15T05:49:09Z', 'content': 'Tesla Inc (NASDAQ:TSLA) experienced a notable insider sell on March 12, 2024, according to a recent SEC filing. Director Robyn Denholm sold 93,705 shares of the company at an average price of $175.44… [+2467 chars]'}, {'source': {'id': None, 'name': 'Marketscreener.com'}, 'author': 'Adrien Chavanne', 'title': 'Tesla, Inc. : Tesla: Who broke the machine?', 'descript
# ...

# %%
threeArticles = articles[:3]
print(threeArticles)
# Out:
# [{'source': {'id': None, 'name': 'Yahoo Entertainment'}, 'author': 'GuruFocus Research', 'title': 'Director Robyn Denholm Sells 93,705 Shares of Tesla Inc (TSLA)', 'description': 'Tesla Inc (NASDAQ:TSLA) experienced a notable insider sell on March 12, 2024, according to a recent SEC filing.', 'url': 'https://finance.yahoo.com/news/director-robyn-denholm-sells-93-054909107.html', 'urlToImage': 'https://s.yimg.com/ny/api/res/1.2/br9qC.j2W5V0SlLpFN5Uzw--/YXBwaWQ9aGlnaGxhbmRlcjt3PTEyMDA7aD01MjU-/https://media.zenfs.com/en/us.finance.gurufocus/9743aa0b0ee97fcab89e0e9854bfb79c', 'publishedAt': '2024-03-15T05:49:09Z', 'content': 'Tesla Inc (NASDAQ:TSLA) experienced a notable insider sell on March 12, 2024, according to a recent SEC filing. Director Robyn Denholm sold 93,705 shares of the company at an average price of $175.44… [+2467 chars]'}, {'source': {'id': None, 'name': 'Marketscreener.com'}, 'author': 'Adrien Chavanne', 'title': 'Tesla, Inc. : Tesla: Who broke the machine?', 'descript
# ...

# %%
formattedArticles = [f"Headline: {article['title']}. \nBrief: {article['description']}" for article in threeArticles]
print(formattedArticles)
# Out:
# ['Headline: Director Robyn Denholm Sells 93,705 Shares of Tesla Inc (TSLA). \nBrief: Tesla Inc (NASDAQ:TSLA) experienced a notable insider sell on March 12, 2024, according to a recent SEC filing.', 'Headline: Tesla, Inc. : Tesla: Who broke the machine?. \nBrief: (marketscreener.com) The electric carmaker is in a bad way. Its share price fell more than 5% during the last session on Wall Street. https://www.marketscreener.com/quote/stock/TESLA-INC-6344549/news/Tesla-Inc-Tesla-Who-broke-the-machine-46346941/?utm_medium=…', 'Headline: Wesbanco Bank Inc. Reduces Stock Position in Tesla, Inc. (NASDAQ:TSLA). \nBrief: Wesbanco Bank Inc. reduced its holdings in Tesla, Inc. (NASDAQ:TSLA – Free Report) by 23.4% in the third quarter, according to its most recent filing with the Securities & Exchange Commission. The institutional investor owned 7,142 shares of the electric vehi…']

# %% [markdown]
# #  App passwords of gmail :dilq imhx zslj euwl

# %%
import smtplib

myEmail = "yuyumumuiris@gmail.com"
password = "dilqimhxzsljeuwl"

with smtplib.SMTP("smtp.gmail.com") as connection:
    connection.starttls()
    connection.login(user=myEmail, password=password)
    connection.sendmail(
        from_addr=myEmail,
        to_addrs="ylzhao.iris@gmail.com",
        msg="Subject:StockNews\n\n body"

    )
# Out:
# ---------------------------------------------------------------------------
# SMTPAuthenticationError                   Traceback (most recent call last)
# Cell In[17], line 8
#       6 with smtplib.SMTP("smtp.gmail.com") as connection:
#       7     connection.starttls()
# ----> 8     connection.login(user=myEmail, password=password)
#       9     connection.sendmail(
#      10         from_addr=myEmail,
#      11         to_addrs="ylzhao.iris@gmail.com",
#      12         msg="Subject:StockNews\n\n body"
#      13
#      14     )
#
# File ~/anaconda3/lib/python3.11/smtplib.py:750, in SMTP.login(self, user, password, initial_response_ok)
#     747         last_exception = e
#     749 # We could not login successfully.  Return result of last attempt.
# --> 750 raise last_exception
#
# File ~/anaconda3/lib/python3.11/smtplib.py:739, in SMTP.login(self, user, password, initial_response_ok)
#     737 method_name = 'auth_' + authmethod.lower().replace('-', '_')
#     738 try:
# ...

# %%
pip install tensorflow
# Out:
# ...
#   Obtaining dependency information for keras>=3.0.0 from https://files.pythonhosted.org/packages/48/a6/ac5cc97a2677e07d3ac359d05cfb2974ec16c8c8ae6dd265e94706256608/keras-3.2.1-py3-none-any.whl.metadata
#   Using cached keras-3.2.1-py3-none-any.whl.metadata (5.6 kB)
# ...
# Using cached keras-3.2.1-py3-none-any.whl (1.1 MB)
# ...
#   Attempting uninstall: keras
#     Found existing installation: keras 2.10.0
#     Uninstalling keras-2.10.0:
#       Successfully uninstalled keras-2.10.0
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pydotplus
# Out:
# Retrieving notices: ...working... DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/notices.json HTTP/1.1" 404 None
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/notices.json HTTP/1.1" 404 None
# done
# ...
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): repo.anaconda.com:443
# - DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/r/osx-arm64/current_repodata.json HTTP/1.1" 304 0
# DEBUG:urllib3.connectionpool:https://repo.anaconda.com:443 "GET /pkgs/main/osx-arm64/current_repodata.json HTTP/1.1" 200 None
# ...
